# %%
import mysql.connector
from dotenv import load_dotenv
from datetime import datetime
import pandas as pd
import os
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker

pd.set_option('precision', 2)

# %%
def connect_to_SQL():
    load_dotenv()
    username, password = os.getenv("USERNAME"), os.getenv("PASSWORD")
    conn = mysql.connector.connect(user=os.getenv("USERNAME"), password=os.getenv("PASSWORD"),
                                   host='127.0.0.1')
    engine = create_engine(f'mysql+pymysql://{username}:{password}@localhost/baseballStats_db')
    cursor = conn.cursor()
    return cursor, conn, engine

# %%
cursor, conn, engine = connect_to_SQL()
connection = engine.connect()

# %%
career_pitching_df = pd.read_sql('CareerPitchingStats', engine, index_col = ['PlayerID'])
player_bios = pd.read_sql('PlayerBios', engine, index_col='PlayerID')
player_names = pd.read_sql('PlayerNames', engine, index_col='PlayerID')
hall_of_fame = pd.read_sql('HallOfFame', engine, index_col = 'PlayerID')

# %%
career_pitching_df = career_pitching_stats.join(player_bios, on = ['PlayerID'])
career_pitching_df = career_pitching_df.join(player_names, on = ['PlayerID'])
career_pitching_df = career_pitching_df.join(hall_of_fame, on = ['PlayerID'])

# fill in NaN values for HOF
career_pitching_df = career_pitching_df.fillna(0)
career_pitching_df
# Out:
#           Games  GamesStarted  CompleteGames  Shutouts  GamesFinished  Saves  \
# PlayerID
# aardd001    331             0              0         0            141     69
# aased001    448            91             22         5            235     82
# abadf001    384             6              0         0             97      2
# abbog001    248           206             37         5             13      0
# abboj001    263           254             31         6              5      0
# ...         ...           ...            ...       ...            ...    ...
# zimmk001     31             1              0         0              7      0
# zitob001    433           421             12         5              9      0
# zumaj001    171             0              0         0             35      5
# zuveg101    265            31              9         2            139     40
# zycht001     70             1              0         0             14      1
#
#           InningsPitched  Hits    BFP  Homeruns  ...  debutDate  \
# PlayerID                                         ...
# aardd001             337   296   1475        41  ... 2004-04-06
# aased001            1109  1085   4730        89  ... 1977-07-26
# abadf001             330   309   1399        42  ... 2010-07-28
# abbog001            1286  1405   5508       162  ... 1973-07-29
# abboj001            1674  1779   7211       154  ... 1989-04-08
# ...                  ...   ...    ...       ...  ...        ...
# zimmk001              41    42    193         2  ... 2019-03-31
# zitob001            2576  2381  11001       282  ... 2000-07-22
# zumaj001             209   169    911        18  ... 2006-04-03
# zuveg101             642   660   2746        56  ... 1951-04-21
# zycht001              72    57    309         3  ... 2015-09-04
#
#           finalGameDate  bats  throws  CareerLength_Years  MonthsExtra  \
# PlayerID
# aardd001     2015-08-23     R       R                  12            4
# aased001     1990-10-03     R       R                  14            2
# abadf001     2019-09-28     L       L                  10            2
# abbog001     1984-08-08     R       R                  11            0
# abboj001     1999-07-21     L       L                  11            3
# ...                 ...   ...     ...                 ...          ...
# zimmk001     2020-09-22     R       R                   2            5
# zitob001     2015-09-30     L       L                  16            2
# zumaj001     2010-06-28     R       R                   5            2
# zuveg101     1959-06-15     R       R                   9            1
# zycht001     2017-08-19     R       R                   3           11
#
#           birthState        birthCountry       PlayerName  YearOfInduction
# PlayerID
# aardd001    Colorado                 USA    David Aardsma              0.0
# aased001  California                 USA         Don Aase              0.0
# abadf001   La Romana  Dominican Republic    Fernando Abad              0.0
# abbog001    Arkansas                 USA     Glenn Abbott              0.0
# abboj001    Michigan                 USA       Jim Abbott              0.0
# ...              ...                 ...              ...              ...
# zimmk001  California                 USA      Kyle Zimmer              0.0
# zitob001      Nevada                 USA       Barry Zito              0.0
# zumaj001  California                 USA      Joel Zumaya              0.0
# zuveg101    Michigan                 USA  George Zuverink              0.0
# zycht001    Illinois                 USA        Tony Zych              0.0
#
# [4647 rows x 41 columns]

# %% [markdown]
# #### Average Playing Career Length For Pitchers

# %%
print('Average Career Length for Pitchers in our database was {:.2f} years'.format(career_pitching_df['CareerLength_Years'].mean()))
# Out:
# Average Career Length for Pitchers in our database was 6.79 years

# %% [markdown]
# #### Difference in dominant throwing hand between pitchers

# %%
dominant_hand_stats = dict(career_pitching_df['throws'].value_counts())

dominant_hand_dict = {'R': 'Righty', 'L': 'Lefty', 'B': 'Both'}

for key, value in dominant_hand_stats.items():
    print(str(dominant_hand_dict[key]) +':' ,value)
# Out:
# Righty: 3325
# Lefty: 1321
# Both: 1

# %%
def getDecade(series):
    debut_date, final_game = series['debutDate'], series['finalGameDate']
    avg_year = (final_game.year + debut_date.year)/2
    
    decade = round(avg_year/10)*10
    
    
    
    
    return decade

# %%
career_pitching_df_copy = career_pitching_df.copy()
career_pitching_df_copy['Decade Played In'] = career_pitching_df_copy.apply(getDecade, axis =1)
career_pitching_df_copy
# Out:
#           Games  GamesStarted  CompleteGames  Shutouts  GamesFinished  Saves  \
# PlayerID
# aardd001    331             0              0         0            141     69
# aased001    448            91             22         5            235     82
# abadf001    384             6              0         0             97      2
# abbog001    248           206             37         5             13      0
# abboj001    263           254             31         6              5      0
# ...         ...           ...            ...       ...            ...    ...
# zimmk001     31             1              0         0              7      0
# zitob001    433           421             12         5              9      0
# zumaj001    171             0              0         0             35      5
# zuveg101    265            31              9         2            139     40
# zycht001     70             1              0         0             14      1
#
#           InningsPitched  Hits    BFP  Homeruns  ...  finalGameDate  bats  \
# PlayerID                                         ...
# aardd001             337   296   1475        41  ...     2015-08-23     R
# aased001            1109  1085   4730        89  ...     1990-10-03     R
# abadf001             330   309   1399        42  ...     2019-09-28     L
# abbog001            1286  1405   5508       162  ...     1984-08-08     R
# abboj001            1674  1779   7211       154  ...     1999-07-21     L
# ...                  ...   ...    ...       ...  ...            ...   ...
# zimmk001              41    42    193         2  ...     2020-09-22     R
# zitob001            2576  2381  11001       282  ...     2015-09-30     L
# zumaj001             209   169    911        18  ...     2010-06-28     R
# zuveg101             642   660   2746        56  ...     1959-06-15     R
# zycht001              72    57    309         3  ...     2017-08-19     R
#
#           throws  CareerLength_Years  MonthsExtra  birthState  \
# PlayerID
# aardd001       R                  12            4    Colorado
# aased001       R                  14            2  California
# abadf001       L                  10            2   La Romana
# abbog001       R                  11            0    Arkansas
# abboj001       L                  11            3    Michigan
# ...          ...                 ...          ...         ...
# zimmk001       R                   2            5  California
# zitob001       L                  16            2      Nevada
# zumaj001       R                   5            2  California
# zuveg101       R                   9            1    Michigan
# zycht001       R                   3           11    Illinois
#
#                 birthCountry       PlayerName  YearOfInduction  \
# PlayerID
# aardd001                 USA    David Aardsma              0.0
# aased001                 USA         Don Aase              0.0
# abadf001  Dominican Republic    Fernando Abad              0.0
# abbog001                 USA     Glenn Abbott              0.0
# abboj001                 USA       Jim Abbott              0.0
# ...                      ...              ...              ...
# zimmk001                 USA      Kyle Zimmer              0.0
# zitob001                 USA       Barry Zito              0.0
# zumaj001                 USA      Joel Zumaya              0.0
# zuveg101                 USA  George Zuverink              0.0
# zycht001                 USA        Tony Zych              0.0
#
#           Decade Played In
# PlayerID
# aardd001              2010
# aased001              1980
# abadf001              2010
# abbog001              1980
# abboj001              1990
# ...                    ...
# zimmk001              2020
# zitob001              2010
# zumaj001              2010
# zuveg101              1960
# zycht001              2020
#
# [4647 rows x 42 columns]

# %%
decade_group_by = career_pitching_df_copy.groupby('Decade Played In')
decade_group_by.mean()
# Out:
#                    Games  GamesStarted  CompleteGames  Shutouts  \
# Decade Played In
# 1950              216.32        115.34          45.57      8.05
# 1960              178.61         71.50          19.64      4.31
# 1970              196.99         78.08          19.85      4.91
# 1980              207.88         84.79          17.57      4.07
# 1990              201.62         64.38           7.79      2.17
# 2000              201.14         55.20           2.91      0.94
# 2010              188.22         51.52           1.58      0.68
# 2020              104.61         24.90           0.32      0.17
#
#                   GamesFinished  Saves  InningsPitched    Hits      BFP  \
# Decade Played In
# 1950                      54.57  11.80          973.49  957.71  4176.72
# 1960                      53.43  13.10          643.90  624.01  2744.30
# 1970                      58.09  15.00          699.63  657.72  2960.53
# 1980                      62.19  16.16          745.99  734.34  3176.27
# 1990                      62.31  19.47          584.52  576.50  2497.49
# 2000                      53.56  14.18          495.50  510.42  2154.07
# 2010                      44.62  11.23          447.01  440.81  1914.14
# 2020                      24.19   6.42          221.66  211.61   945.72
#
#                   Homeruns  ...   Wins  Losses   ERA  RunSupport    PW  \
# Decade Played In            ...
# 1950                 80.28  ...  56.78   53.21  4.41        4.23  2.25
# 1960                 62.88  ...  35.66   36.44  4.51        3.75  0.25
# 1970                 59.75  ...  39.59   38.62  4.04        3.31  0.37
# 1980                 63.31  ...  41.43   41.61  4.28        3.71  0.56
# 1990                 55.85  ...  32.95   32.79  4.59        3.25  0.79
# 2000                 58.47  ...  27.66   28.06  5.23        3.32  0.20
# 2010                 51.29  ...  25.45   24.94  4.87        2.75  0.38
# 2020                 28.21  ...  12.41   12.34  4.83        2.68  0.34
#
#                   AVGGamesPerYear  careerLength  CareerLength_Years  \
# Decade Played In
# 1950                        20.88          9.49                9.49
# 1960                        20.87          7.12                7.12
# 1970                        23.11          7.38                7.38
# 1980                        22.95          7.69                7.69
# 1990                        22.92          7.52                7.52
# 2000                        23.15          7.32                7.32
# 2010                        23.88          6.81                6.81
# 2020                        21.32          4.38                4.38
#
#                   MonthsExtra  YearOfInduction
# Decade Played In
# 1950                     4.78            53.37
# 1960                     4.14            43.92
# 1970                     4.38            27.99
# 1980                     4.09            36.21
# 1990                     4.91            11.40
# 2000                     4.47            16.06
# 2010                     4.64             2.14
# 2020                     3.65             0.00
#
# [8 rows x 34 columns]
