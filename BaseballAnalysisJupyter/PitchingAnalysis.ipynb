# %%
import mysql.connector
from dotenv import load_dotenv
from datetime import datetime
import pandas as pd
import os
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker

pd.set_option('precision', 2)

# %%
def connect_to_SQL():
    load_dotenv()
    username, password = os.getenv("USERNAME"), os.getenv("PASSWORD")
    conn = mysql.connector.connect(user=os.getenv("USERNAME"), password=os.getenv("PASSWORD"),
                                   host='127.0.0.1')
    engine = create_engine(f'mysql+pymysql://{username}:{password}@localhost/baseballStats_db')
    cursor = conn.cursor()
    return cursor, conn, engine

# %%
cursor, conn, engine = connect_to_SQL()
connection = engine.connect()

# %%
pitching_stats_df = pd.read_sql('CareerPitchingStats', engine, index_col = ['PlayerID'])
pitching_stats_df
# Out:
#           Games  GamesStarted  CompleteGames  Shutouts  GamesFinished  Saves  \
# PlayerID
# aardd001    331             0              0         0            141     69
# aased001    448            91             22         5            235     82
# abadf001    384             6              0         0             97      2
# abbog001    248           206             37         5             13      0
# abboj001    263           254             31         6              5      0
# ...         ...           ...            ...       ...            ...    ...
# zimmk001     31             1              0         0              7      0
# zitob001    433           421             12         5              9      0
# zumaj001    171             0              0         0             35      5
# zuveg101    265            31              9         2            139     40
# zycht001     70             1              0         0             14      1
#
#           InningsPitched  Hits    BFP  Homeruns  ...  Triples  \
# PlayerID                                         ...
# aardd001             337   296   1475        41  ...        4
# aased001            1109  1085   4730        89  ...       28
# abadf001             330   309   1399        42  ...        5
# abbog001            1286  1405   5508       162  ...       39
# abboj001            1674  1779   7211       154  ...       18
# ...                  ...   ...    ...       ...  ...      ...
# zimmk001              41    42    193         2  ...        1
# zitob001            2576  2381  11001       282  ...       46
# zumaj001             209   169    911        18  ...        5
# zuveg101             642   660   2746        56  ...       16
# zycht001              72    57    309         3  ...        1
#
#           GroundedIntoDoublePlays  ROE  Wins  Losses   ERA  RunSupport   PW  \
# PlayerID
# aardd001                       21    8    16      18  4.27        0.00  2.1
# aased001                      106   57    66      60  3.80        4.56  4.5
# abadf001                       25   17     8      29  3.67        1.67  0.4
# abbog001                      111   81    62      83  4.39        4.23 -7.4
# abboj001                      200  112    87     108  4.25        4.26  0.1
# ...                           ...  ...   ...     ...   ...         ...  ...
# zimmk001                        4    3     1       1  5.66        3.00 -0.1
# zitob001                      219  106   165     143  4.04        4.53  5.1
# zumaj001                       10   13    13      12  3.05        0.00  2.7
# zuveg101                       58   57    32      36  3.54        3.45  1.1
# zycht001                        6    1     7       3  2.72        6.00  1.7
#
#           AVGGamesPerYear  careerLength
# PlayerID
# aardd001            27.58            12
# aased001            32.00            14
# abadf001            38.40            10
# abbog001            22.55            11
# abboj001            23.91            11
# ...                   ...           ...
# zimmk001            15.50             2
# zitob001            27.06            16
# zumaj001            34.20             5
# zuveg101            29.44             9
# zycht001            23.33             3
#
# [4647 rows x 31 columns]
